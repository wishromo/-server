# %% [markdown]
# <a href="https://colab.research.google.com/github/wishromo/-server/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for x in range(1, 4):
    for y in range(1, 5):
        print("1st loop =", x, "2nd loop =", y)
# Out:
# 1st loop = 1 2nd loop = 1
# 1st loop = 1 2nd loop = 2
# 1st loop = 1 2nd loop = 3
# 1st loop = 1 2nd loop = 4
# 1st loop = 2 2nd loop = 1
# 1st loop = 2 2nd loop = 2
# 1st loop = 2 2nd loop = 3
# 1st loop = 2 2nd loop = 4
# 1st loop = 3 2nd loop = 1
# 1st loop = 3 2nd loop = 2
# 1st loop = 3 2nd loop = 3
# 1st loop = 3 2nd loop = 4

# %%
color = ["red", "green", "blue"]
fruits = ["apple", "banana", "grapes"]

for x in color:
    for y in fruits:
        print(x, y)
# Out:
# red apple
# red banana
# red grapes
# green apple
# green banana
# green grapes
# blue apple
# blue banana
# blue grapes

# %%
thislist = ["orange", "banana", "apple"]
thislist[1] = "grapes"

print(thislist)
# Out:
# ['orange', 'grapes', 'apple']

# %%
thislist = ["orange", "banana", "apple"]
z="apple"
if z in thislist:
  print("yes apple is in fruit list")
# Out:
# yes apple is in fruit list

# %%
thislist = ["orange", "banana", "apple"]
print(len(thislist))
# Out:
# 3

# %%
thislist = ["orange", "banana", "apple"]
thislist.append("orange")
print(thislist)
# Out:
# ['orange', 'banana', 'apple', 'orange']

# %%
thislist = ["orange", "banana", "apple"]
thislist.insert(1,"orange")
print(thislist)
# Out:
# ['orange', 'orange', 'banana', 'apple']

# %%
thislist = ["orange", "banana", "apple"]
thislist.pop(1)
print(thislist)
# Out:
# ['orange', 'apple']

# %%
thislist = ["orange", "banana", "apple"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
thislist = ["orange", "banana", "apple"]
mylist=list(thislist)
print(mylist)
# Out:
# ['orange', 'banana', 'apple']

# %%
thislist = {"orange", "banana", "apple"}
print(type(thislist))
mylist=list(thislist)
print(type(mylist))
# Out:
# <class 'set'>
# <class 'list'>

# %%
fruits = []
fruits.append("apple")
print(fruits)
fruits.append("banana")
print(fruits)
fruits.append("mango")
print(fruits)
# Out:
# ['apple']
# ['apple', 'banana']
# ['apple', 'banana', 'mango']

# %%
no=[10,20,30,40,50]
no.insert(2,25)
print(no)
# Out:
# [10, 20, 25, 30, 40, 50]

# %%
list1=[1,2,3]
list2=[4,5,6]
print(list1)
list1.extend(list2)
print(list1)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4, 5, 6]

# %%
color=["red","green","yellow"]
color.remove("green")
print(color)
# Out:
# ['red', 'yellow']

# %%
cities=["lahore","islamabad","karachi"]
print(cities)
cities.pop()
print(cities)
# Out:
# ['lahore', 'islamabad', 'karachi']
# ['lahore', 'islamabad']

# %%
student=["ali","sarah","ahmad"]
x="ahmad"
if x in student:
 print (student.index(x))
# Out:
# 2

# %%
def square(x):
  return(x*x)
x=square(5)
print(x)
# Out:
# 25

# %%
from collections import Counter

s = [1, 2, 4, 5, 5, 7, 8, 8]

x = Counter(s)

print("Number of occurrences of 5:", x[5])
print("Number of occurrences of 7:", x[7])
# Out:
# Number of occurrences of 5: 2
# Number of occurrences of 7: 1

# %%
color=("red","blue","green","yellow")
print(color)
print(color[0])
print(color[3])
# Out:
# ('red', 'blue', 'green', 'yellow')
# red
# yellow

# %%
n0 = (10, 20, 30, 40, 50)

print(n0[0:2])   # (10, 20)
print(n0[2:5])   # (30, 40, 50)
print(n0[:3])    # (10, 20, 30)
print(n0[2:])    # (30, 40, 50)
print(n0[:])     # (10, 20, 30, 40, 50)
print(n0[-2:])   # (40, 50)
# Out:
# (10, 20)
# (30, 40, 50)
# (10, 20, 30)
# (30, 40, 50)
# (10, 20, 30, 40, 50)
# (40, 50)

# %%
from collections import Counter

s = (1, 2, 4, 5, 5, 7, 8, 8,8)

x = Counter(s)

print("Number of occurrences of 5:", x[5])
print("Number of occurrences of 7:", x[7])
print("Number of occurrences of 7:", x[8])
# Out:
# Number of occurrences of 5: 2
# Number of occurrences of 7: 1
# Number of occurrences of 7: 3

# %%
student=("ali","sarah","ahmad")
x="ahmad"
if x in student:
 print (student.index(x))
# Out:
# 2

# %%
fruits = ("apple", "banana", "orange")
print(fruits)
fruits_list = list(fruits)

fruits_list.append("mango")

print(fruits_list)
# Out:
# ('apple', 'banana', 'orange')
# ['apple', 'banana', 'orange', 'mango']

# %%
data=(5,10,15,20,25,30)
print(len(data))
# Out:
# 6

# %%
marks = [75, 55, 50, 40, 88, 34]

marks.sort()

print(marks)

marks.sort(reverse=True)
print(marks)
marks.reverse()
print("use to reverse",marks)
# Out:
# [34, 40, 50, 55, 75, 88]
# [88, 75, 55, 50, 40, 34]
# use to reverse [34, 40, 50, 55, 75, 88]

# %%
list1 = [10, 20, 30]

list2 = list1.copy()

print("List1:", list1)

list1.append(40)

print("List1 after append:", list1)
print("List2:", list2)
# Out:
# List1: [10, 20, 30]
# List1 after append: [10, 20, 30, 40]
# List2: [10, 20, 30]
